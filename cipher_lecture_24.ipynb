# %% [markdown]
# <a href="https://colab.research.google.com/github/Vidushi2601/CipherSchools-DataSci-ML-Hybrid/blob/main/cipher_lecture_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Correlation Concept

# %%
#It measures the stength and direction of linear relationship that occurs bw two variables


import pandas as pd
import numpy as np


#Seed for reproductivity
np.random.seed(42)

#Generate sample data
data={
    'Age': np.random.normal(30,10,100).astype(int),
    'Annual Income(K)': np.random.normal(50,20,100).astype(int),
    'Spending Score(1-100)':np.random.randint(1,100,100),
    'Years with Company': np.random.normal(5,2,100).astype(int)

}

#Create DataFrame
df=pd.DataFrame(data)
df
# Out:
#     Age  Annual Income  Spending Score(1-100)  Years with Company
# 0    34             21                      2                   7
# 1    28             41                     90                   3
# 2    36             43                     17                   5
# 3    45             33                     33                   6
# 4    27             46                      9                   3
# ..  ...            ...                    ...                 ...
# 95   15             57                     22                   7
# 96   32             32                     93                   6
# 97   32             53                     67                   4
# 98   30             51                     76                   4
# 99   27             27                     26                   2
#
# [100 rows x 4 columns]

# %%
from tabulate import tabulate

# %%
correlation_matrix=df.corr()

#print the correlation matrix as a table
print(tabulate(correlation_matrix,headers='keys',tablefmt='grid',numalign='right',floatfmt=".2f"))
# Out:
# +-----------------------+-------+-----------------+-------------------------+----------------------+
# |                       |   Age |   Annual Income |   Spending Score(1-100) |   Years with Company |
# +=======================+=======+=================+=========================+======================+
# | Age                   |  1.00 |           -0.13 |                    0.02 |                 0.01 |
# +-----------------------+-------+-----------------+-------------------------+----------------------+
# | Annual Income         | -0.13 |            1.00 |                    0.02 |                -0.13 |
# +-----------------------+-------+-----------------+-------------------------+----------------------+
# | Spending Score(1-100) |  0.02 |            0.02 |                    1.00 |                -0.13 |
# +-----------------------+-------+-----------------+-------------------------+----------------------+
# ...
